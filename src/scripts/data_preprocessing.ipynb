# %%
import pandas as pd
import json

# %%
# 0 - Read xlsx spreadsheet

df = pd.read_excel(r'C:\Users\ling9846\Documents\Copy of Case-Ownership-by-Products.xlsx', 
                   sheet_name='Product by PQ and Tech',
                   na_filter=False)
df.head()
# Out:
#                      Product         Online    Desktop         Enterprise  \
# 0       AppStudio for ArcGIS  Online - Apps             Enterprise - Apps
# 1          ArcGIS 3D Analyst                 Pro - Ext   Enterprise - Ext
# 2   ArcGIS Analytics for IoT                             Enterprise - Ext
# 3  ArcGIS API for JavaScript
# 4      ArcGIS API for Python  Online - Core             Enterprise - Core
#
#              SDK Data Management Implementation Professional Services  \
# 0  SDK - Runtime
# 1
# 2
# 3      SDK - Web
# 4
#
#      Support Method Reference
# 0  Support Services
# 1  Support Services
# 2  Support Services
# 3  Support Services
# 4  Support Services

# %%
# 1 - Create subset of df with all columns for queues

# df_subset = df[["Online", "Desktop", "Enterprise", "SDK", "Data Management", "Implementation", "Professional Services"]]
df_subset = df[df.columns[1:8]]
df_subset.head()
# Out:
#           Online    Desktop         Enterprise            SDK Data Management  \
# 0  Online - Apps             Enterprise - Apps  SDK - Runtime
# 1                 Pro - Ext   Enterprise - Ext
# 2                             Enterprise - Ext
# 3                                                   SDK - Web
# 4  Online - Core             Enterprise - Core
#
#   Implementation Professional Services
# 0
# 1
# 2
# 3
# 4

# %%
# 2 - List possible values for Technology and Queue  

Technologies = [""] * df_subset.shape[1]
Queues = [""] * df_subset.shape[1]

for i in range(0, df_subset.shape[1]):
    Technologies[i] = df_subset.columns[i].replace(" ", "")
    column = set(df_subset[df_subset.columns[i]])
    Queues[i] = list(filter(None, column))

print(Technologies)    
print(Queues)
# Out:
# ['Online', 'Desktop', 'Enterprise', 'SDK', 'DataManagement', 'Implementation', 'ProfessionalServices']
# [['Online - Outage', 'Online - Core', 'Online - Admin', 'Online - Apps'], ['Pro - Ext', 'ArcMap', 'Pro - Core'], ['Enterprise - Ext', 'Enterprise - Core', 'Enterprise - Apps'], ['SDK - Runtime', 'SDK - Web', 'SDK - Native'], ['Pro - Data', 'Enterprise - Data'], ['Enterprise - Setup', 'Online - Setup', 'Pro - Setup', 'ArcMap - Setup'], ['Managed Cloud Services', 'Solutions - Products']]

# %%
# 3 - Join queues to corresponding technology

tech_queue = {}

for index in range(0, len(Technologies)):
    tech_queue[Technologies[index]] = [Queues[index]]

df_tech_queue = pd.DataFrame(tech_queue)
df_tech_queue
# Out:
#                                               Online  \
# 0  [Online - Outage, Online - Core, Online - Admi...
#
#                            Desktop  \
# 0  [Pro - Ext, ArcMap, Pro - Core]
#
#                                           Enterprise  \
# 0  [Enterprise - Ext, Enterprise - Core, Enterpri...
#
#                                         SDK                   DataManagement  \
# 0  [SDK - Runtime, SDK - Web, SDK - Native]  [Pro - Data, Enterprise - Data]
#
#                                       Implementation  \
# 0  [Enterprise - Setup, Online - Setup, Pro - Set...
#
#                              ProfessionalServices
# 0  [Managed Cloud Services, Solutions - Products]

# %%
# 4 - Export df_tech_queue to JSON

json_tech_queue = df_tech_queue.to_json(r'C:\Users\ling9846\Downloads\tech_queue.json', orient="records")

# %%
# 5 - Create new column for technology and combine queues to one column

Technology = [""] * df_subset.shape[0]
Queue = [""] * df_subset.shape[0]

for i in range(0, df_subset.shape[0]):
    for j in range(0, df_subset.shape[1]):
        if df_subset.iloc[i, j] != "":
            Technology[i] += df_subset.columns[j] + ", "
            Queue[i] += df_subset.iloc[i, j] + ", "
            
print(Technology)
print(Queue)
# Out:
# ['Online, Enterprise, SDK, ', 'Desktop, Enterprise, ', 'Enterprise, ', 'SDK, ', 'Online, Enterprise, ', 'Desktop, Implementation, ', 'Enterprise, Implementation, ', 'Online, ', 'Online, Enterprise, ', 'Online, ', 'Desktop, Enterprise, ', 'Desktop, Enterprise, ', 'Desktop, Data Management, Implementation, ', 'Desktop, ', '', 'SDK, ', 'Enterprise, Data Management, Implementation, ', 'Enterprise, ', 'Online, SDK, ', 'Desktop, Enterprise, ', 'Desktop, Enterprise, ', 'Desktop, Enterprise, ', 'Online, Desktop, Enterprise, Data Management, ', 'Online, Desktop, Enterprise, Data Management, ', 'Online, Desktop, Enterprise, Data Management, ', 'Online, Desktop, Enterprise, Data Management, ', 'Professional Services, ', 'Online, Desktop, Enterprise, Data Management, ', 'Desktop, Enterprise, ', 'Desktop, Enterprise, ', 'Desktop, Enterprise, ', '', 'Online, Desktop, Enterprise, Data Management, ', '', 'Online, Desktop, Enterprise, Data Management, ', 'Online, Desktop, Enterprise, Data Management, ', 'Desktop, ', 'Enterprise, Implementation, ', 'Enterprise, Implementation, ', 'Desktop, Enterprise, ', 'Online, ', 'Desktop, Enterprise, ', 'Enterprise, Implementation, ', 'Desktop, Enterprise, ', 'Desktop, ', 'Enterprise, ', 'Online, Enterprise, ', 'Desktop, Enterprise, ', 'Online, ', 'Online, Enterprise, ', 'Enterprise, ', 'Enterprise, ', 'Enterprise, Implementation, ', 'Enterprise, Implementation, ', 'Desktop, Enterprise, ', 'Enterprise, ', 'Online, Implementation, ', 'Online, ', 'Online, ', 'Online, ', 'Desktop, Enterprise, Data Management, ', 'Online, Desktop, Enterprise, Data Management, Implementation, ', 'Desktop, ', 'Online, Enterprise, ', 'SDK, ', 'Desktop, Enterprise, Data Management, ', 'Desktop, Enterprise, ', 'Online, Enterprise, ', 'Online, Enterprise, ', 'Enterprise, ', 'Enterprise, Data Management, ', 'Data Management, ', 'SDK, ', 'Desktop, ', 'Desktop, Enterprise, Data Management, ', 'Desktop, ', 'Online, Enterprise, ', 'Online, Enterprise, ', 'Online, ', 'Enterprise, ', '', 'Desktop, ', 'Desktop, ', 'Professional Services, ', 'Online, ', 'Professional Services, ', 'Professional Services, ', 'Desktop, ', '', '', 'Desktop, Enterprise, ', 'Professional Services, ', 'Online, Enterprise, ', 'Desktop, ', 'Online, Enterprise, ', 'Enterprise, ', 'Online, Enterprise, ', 'Desktop, Enterprise, Data Management, ', 'SDK, ', '', 'Desktop, ', 'Online, Enterprise, ', 'Online, ', 'Online, Enterprise, ', 'Online, Enterprise, ', 'SDK, ', '', 'Online, Enterprise, ', 'Online, Enterprise, ']
# ['Online - Apps, Enterprise - Apps, SDK - Runtime, ', 'Pro - Ext, Enterprise - Ext, ', 'Enterprise - Ext, ', 'SDK - Web, ', 'Online - Core, Enterprise - Core, ', 'Pro - Ext, ArcMap - Setup, ', 'Enterprise - Ext, Enterprise - Setup, ', 'Online - Apps, ', 'Online - Apps, Enterprise - Ext, ', 'Online - Apps, ', 'Pro - Ext, Enterprise - Ext, ', 'Pro - Ext, Enterprise - Ext, ', 'ArcMap, Pro - Data, ArcMap - Setup, ', 'Pro - Core, ', '', 'SDK - Native, ', 'Enterprise - Core, Enterprise - Data, Enterprise - Setup, ', 'Enterprise - Ext, ', 'Online - Apps, SDK - Web, ', 'Pro - Core, Enterprise - Ext, ', 'Pro - Ext, Enterprise - Ext, ', 'Pro - Ext, Enterprise - Ext, ', 'Online - Core, Pro - Core, Enterprise - Core, Pro - Data, ', 'Online - Core, Pro - Core, Enterprise - Core, Enterprise - Data, ', 'Online - Core, Pro - Core, Enterprise - Core, Pro - Data, ', 'Online - Core, Pro - Core, Enterprise - Core, Enterprise - Data, ', 'Solutions - Products, ', 'Online - Core, Pro - Core, Enterprise - Core, Pro - Data, ', 'Pro - Ext, Enterprise - Ext, ', 'Pro - Ext, Enterprise - Ext, ', 'Pro - Ext, Enterprise - Ext, ', '', 'Online - Core, Pro - Core, Enterprise - Core, Pro - Data, ', '', 'Online - Core, Pro - Core, Enterprise - Core, Pro - Data, ', 'Online - Core, Pro - Core, Enterprise - Core, Enterprise - Data, ', 'Pro - Ext, ', 'Enterprise - Ext, Enterprise - Setup, ', 'Enterprise - Ext, Enterprise - Setup, ', 'Pro - Ext, Enterprise - Ext, ', 'Online - Apps, ', 'Pro - Ext, Enterprise - Ext, ', 'Enterprise - Ext, Enterprise - Setup, ', 'Pro - Ext, Enterprise - Ext, ', 'Pro - Core, ', 'Enterprise - Ext, ', 'Online - Core, Enterprise - Core, ', 'Pro - Ext, Enterprise - Ext, ', 'Online - Apps, ', 'Online - Apps, Enterprise - Apps, ', 'Enterprise - Ext, ', 'Enterprise - Ext, ', 'Enterprise - Ext, Enterprise - Setup, ', 'Enterprise - Ext, Enterprise - Setup, ', 'Pro - Ext, Enterprise - Ext, ', 'Enterprise - Ext, ', 'Online - Core, Online - Setup, ', 'Online - Admin, ', 'Online - Outage, ', 'Online - Apps, ', 'Pro - Ext, Enterprise - Ext, Enterprise - Data, ', 'Online - Core, Pro - Core, Enterprise - Core, Pro - Data, Pro - Setup, ', 'Pro - Core, ', 'Online - Apps, Enterprise - Apps, ', 'SDK - Runtime, ', 'Pro - Ext, Enterprise - Ext, Enterprise - Data, ', 'Pro - Ext, Enterprise - Ext, ', 'Online - Apps, Enterprise - Apps, ', 'Online - Apps, Enterprise - Apps, ', 'Enterprise - Ext, ', 'Enterprise - Ext, Enterprise - Data, ', 'Enterprise - Data, ', 'SDK - Native, ', 'Pro - Ext, ', 'Pro - Core, Enterprise - Core, Pro - Data, ', 'Pro - Core, ', 'Online - Apps, Enterprise - Apps, ', 'Online - Apps, Enterprise - Apps, ', 'Online - Apps, ', 'Enterprise - Core, ', '', 'Pro - Ext, ', 'Pro - Ext, ', 'Solutions - Products, ', 'Online - Apps, ', 'Solutions - Products, ', 'Managed Cloud Services, ', 'Pro - Ext, ', '', '', 'Pro - Ext, Enterprise - Ext, ', 'Solutions - Products, ', 'Online - Apps, Enterprise - Apps, ', 'Pro - Ext, ', 'Online - Apps, Enterprise - Apps, ', 'Enterprise - Ext, ', 'Online - Apps, Enterprise - Apps, ', 'Pro - Ext, Enterprise - Ext, Enterprise - Data, ', 'SDK - Native, ', '', 'Pro - Core, ', 'Online - Apps, Enterprise - Apps, ', 'Online - Core, ', 'Online - Apps, Enterprise - Apps, ', 'Online - Apps, Enterprise - Apps, ', 'SDK - Web, ', '', 'Online - Apps, Enterprise - Apps, ', 'Online - Core, Enterprise - Core, ']

# %%
# 5 - Remove extra commas from technology and queue columns

for i in range(0, df_subset.shape[0]):
    if (Technology[i].endswith(', ')):
        Technology[i] = Technology[i].rstrip(', ')
    if (Queue[i].endswith(', ')):
        Queue[i] = Queue[i].rstrip(', ')

print(Technology)
print(Queue)
# Out:
# ['Online, Enterprise, SDK', 'Desktop, Enterprise', 'Enterprise', 'SDK', 'Online, Enterprise', 'Desktop, Implementation', 'Enterprise, Implementation', 'Online', 'Online, Enterprise', 'Online', 'Desktop, Enterprise', 'Desktop, Enterprise', 'Desktop, Data Management, Implementation', 'Desktop', '', 'SDK', 'Enterprise, Data Management, Implementation', 'Enterprise', 'Online, SDK', 'Desktop, Enterprise', 'Desktop, Enterprise', 'Desktop, Enterprise', 'Online, Desktop, Enterprise, Data Management', 'Online, Desktop, Enterprise, Data Management', 'Online, Desktop, Enterprise, Data Management', 'Online, Desktop, Enterprise, Data Management', 'Professional Services', 'Online, Desktop, Enterprise, Data Management', 'Desktop, Enterprise', 'Desktop, Enterprise', 'Desktop, Enterprise', '', 'Online, Desktop, Enterprise, Data Management', '', 'Online, Desktop, Enterprise, Data Management', 'Online, Desktop, Enterprise, Data Management', 'Desktop', 'Enterprise, Implementation', 'Enterprise, Implementation', 'Desktop, Enterprise', 'Online', 'Desktop, Enterprise', 'Enterprise, Implementation', 'Desktop, Enterprise', 'Desktop', 'Enterprise', 'Online, Enterprise', 'Desktop, Enterprise', 'Online', 'Online, Enterprise', 'Enterprise', 'Enterprise', 'Enterprise, Implementation', 'Enterprise, Implementation', 'Desktop, Enterprise', 'Enterprise', 'Online, Implementation', 'Online', 'Online', 'Online', 'Desktop, Enterprise, Data Management', 'Online, Desktop, Enterprise, Data Management, Implementation', 'Desktop', 'Online, Enterprise', 'SDK', 'Desktop, Enterprise, Data Management', 'Desktop, Enterprise', 'Online, Enterprise', 'Online, Enterprise', 'Enterprise', 'Enterprise, Data Management', 'Data Management', 'SDK', 'Desktop', 'Desktop, Enterprise, Data Management', 'Desktop', 'Online, Enterprise', 'Online, Enterprise', 'Online', 'Enterprise', '', 'Desktop', 'Desktop', 'Professional Services', 'Online', 'Professional Services', 'Professional Services', 'Desktop', '', '', 'Desktop, Enterprise', 'Professional Services', 'Online, Enterprise', 'Desktop', 'Online, Enterprise', 'Enterprise', 'Online, Enterprise', 'Desktop, Enterprise, Data Management', 'SDK', '', 'Desktop', 'Online, Enterprise', 'Online', 'Online, Enterprise', 'Online, Enterprise', 'SDK', '', 'Online, Enterprise', 'Online, Enterprise']
# ['Online - Apps, Enterprise - Apps, SDK - Runtime', 'Pro - Ext, Enterprise - Ext', 'Enterprise - Ext', 'SDK - Web', 'Online - Core, Enterprise - Core', 'Pro - Ext, ArcMap - Setup', 'Enterprise - Ext, Enterprise - Setup', 'Online - Apps', 'Online - Apps, Enterprise - Ext', 'Online - Apps', 'Pro - Ext, Enterprise - Ext', 'Pro - Ext, Enterprise - Ext', 'ArcMap, Pro - Data, ArcMap - Setup', 'Pro - Core', '', 'SDK - Native', 'Enterprise - Core, Enterprise - Data, Enterprise - Setup', 'Enterprise - Ext', 'Online - Apps, SDK - Web', 'Pro - Core, Enterprise - Ext', 'Pro - Ext, Enterprise - Ext', 'Pro - Ext, Enterprise - Ext', 'Online - Core, Pro - Core, Enterprise - Core, Pro - Data', 'Online - Core, Pro - Core, Enterprise - Core, Enterprise - Data', 'Online - Core, Pro - Core, Enterprise - Core, Pro - Data', 'Online - Core, Pro - Core, Enterprise - Core, Enterprise - Data', 'Solutions - Products', 'Online - Core, Pro - Core, Enterprise - Core, Pro - Data', 'Pro - Ext, Enterprise - Ext', 'Pro - Ext, Enterprise - Ext', 'Pro - Ext, Enterprise - Ext', '', 'Online - Core, Pro - Core, Enterprise - Core, Pro - Data', '', 'Online - Core, Pro - Core, Enterprise - Core, Pro - Data', 'Online - Core, Pro - Core, Enterprise - Core, Enterprise - Data', 'Pro - Ext', 'Enterprise - Ext, Enterprise - Setup', 'Enterprise - Ext, Enterprise - Setup', 'Pro - Ext, Enterprise - Ext', 'Online - Apps', 'Pro - Ext, Enterprise - Ext', 'Enterprise - Ext, Enterprise - Setup', 'Pro - Ext, Enterprise - Ext', 'Pro - Core', 'Enterprise - Ext', 'Online - Core, Enterprise - Core', 'Pro - Ext, Enterprise - Ext', 'Online - Apps', 'Online - Apps, Enterprise - Apps', 'Enterprise - Ext', 'Enterprise - Ext', 'Enterprise - Ext, Enterprise - Setup', 'Enterprise - Ext, Enterprise - Setup', 'Pro - Ext, Enterprise - Ext', 'Enterprise - Ext', 'Online - Core, Online - Setup', 'Online - Admin', 'Online - Outage', 'Online - Apps', 'Pro - Ext, Enterprise - Ext, Enterprise - Data', 'Online - Core, Pro - Core, Enterprise - Core, Pro - Data, Pro - Setup', 'Pro - Core', 'Online - Apps, Enterprise - Apps', 'SDK - Runtime', 'Pro - Ext, Enterprise - Ext, Enterprise - Data', 'Pro - Ext, Enterprise - Ext', 'Online - Apps, Enterprise - Apps', 'Online - Apps, Enterprise - Apps', 'Enterprise - Ext', 'Enterprise - Ext, Enterprise - Data', 'Enterprise - Data', 'SDK - Native', 'Pro - Ext', 'Pro - Core, Enterprise - Core, Pro - Data', 'Pro - Core', 'Online - Apps, Enterprise - Apps', 'Online - Apps, Enterprise - Apps', 'Online - Apps', 'Enterprise - Core', '', 'Pro - Ext', 'Pro - Ext', 'Solutions - Products', 'Online - Apps', 'Solutions - Products', 'Managed Cloud Services', 'Pro - Ext', '', '', 'Pro - Ext, Enterprise - Ext', 'Solutions - Products', 'Online - Apps, Enterprise - Apps', 'Pro - Ext', 'Online - Apps, Enterprise - Apps', 'Enterprise - Ext', 'Online - Apps, Enterprise - Apps', 'Pro - Ext, Enterprise - Ext, Enterprise - Data', 'SDK - Native', '', 'Pro - Core', 'Online - Apps, Enterprise - Apps', 'Online - Core', 'Online - Apps, Enterprise - Apps', 'Online - Apps, Enterprise - Apps', 'SDK - Web', '', 'Online - Apps, Enterprise - Apps', 'Online - Core, Enterprise - Core']

# %%
# 5 - Split Reference into Email and URL

df_reference = df[["Reference"]]

Email = [""] * df_reference.shape[0]
URL = [""] * df_reference.shape[0]

for i in range(0, df_reference.shape[0]):
    if ("@" in df_reference.iloc[i, 0]): 
        Email[i] += df_reference.iloc[i, 0]
    else:
        URL[i] += df_reference.iloc[i, 0]

print(Email) 
print(URL)
# Out:
# ['', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', 'districting@esri.com', '', '', '', '', '', '', '', 'redistricting@esri.com', 'demographics@esri.com', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# ['', '', '', '', '', '', '', '', '', '', '', '', '', '', 'https://github.com/Esri/arcgis-osm-editor', '', '', '', '', '', 'https://esri.lightning.force.com/lightning/r/Technical_Article__kav/ka1f20000001GUVAA2/view', 'https://esri.lightning.force.com/lightning/r/Technical_Article__kav/ka1f20000001GUVAA2/view', '', '', '', '', 'https://esri.lightning.force.com/lightning/r/Technical_Article__kav/ka1f20000001GUVAA2/view', '', 'https://esri.lightning.force.com/lightning/r/Technical_Article__kav/ka1f20000001GUVAA2/view', 'https://esri.lightning.force.com/lightning/r/Technical_Article__kav/ka1f20000001GUVAA2/view', 'https://esri.lightning.force.com/lightning/r/Technical_Article__kav/ka1f20000001GUVAA2/view', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', 'https://esri.lightning.force.com/lightning/r/Technical_Article__kav/ka1f2000000LDECAA4/view', '', '', 'https://s3.amazonaws.com/lms-content/Readiness/Enterprise_Apps/ArcGISMonitor/ArcGISMonitorProductSupportability_1061.pdf', '', '', '', '', '', '', 'https://esri.lightning.force.com/lightning/r/Technical_Article__kav/ka1f20000001GUVAA2/view', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', 'https://esri.lightning.force.com/lightning/r/Technical_Article__kav/ka1f20000001GUVAA2/view', '', '', '', '', 'https://esri.lightning.force.com/lightning/r/Technical_Article__kav/ka1f20000001GUVAA2/view', '', '', '', '', '', '', '', '', 'https://esri.lightning.force.com/lightning/r/Technical_Article__kav/ka139000000oTd3AAE/view', '', '', '', '', '', '', 'https://github.com/Esri/geoportal-server/wiki/WMC-Client', '', '']

# %%
# 6 - Combine Technology, Queue, Email, URL back to corresponding product
final = {'product':df["Product"], 
        'technology':Technology, 
        'queue':Queue,
        'supportMethod':df["Support Method"],
        'email':Email,
        'url': URL} 

df_final = pd.DataFrame(final)
df_final.head()
# Out:
#                      product               technology  \
# 0       AppStudio for ArcGIS  Online, Enterprise, SDK
# 1          ArcGIS 3D Analyst      Desktop, Enterprise
# 2   ArcGIS Analytics for IoT               Enterprise
# 3  ArcGIS API for JavaScript                      SDK
# 4      ArcGIS API for Python       Online, Enterprise
#
#                                              queue     supportMethod email url
# 0  Online - Apps, Enterprise - Apps, SDK - Runtime  Support Services
# 1                      Pro - Ext, Enterprise - Ext  Support Services
# 2                                 Enterprise - Ext  Support Services
# 3                                        SDK - Web  Support Services
# 4                 Online - Core, Enterprise - Core  Support Services

# %%
# 7 - Export df_final to JSON

json_final = df_final.to_json(r'C:\Users\ling9846\Downloads\product_tech_queue.json', orient="records")
